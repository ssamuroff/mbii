# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

central_name='most_massive'

# %%
fid = {}
sym = {}

base = '/Users/hattifattener/Documents/ias/mbii/2pt/ns300_nd1000/v9/'
for i in xrange(2):
    for j in xrange(2):
        fid[(i+1,j+1)] = np.loadtxt(base+'ED_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/ED_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        
fid[(0,0)] = np.loadtxt(base+'ED_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
sym[(0,0)] = np.loadtxt(base+'symmetrised/ED_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T

print fid[0,0][2].sum()
print sym[0,0][2].sum()
# Out:
# 0.013559571641905835
# 0.011515615486115061

# %% [markdown]
# ## 3D correlation functions

# %%
#plt.plot(fid[1,1][0], fid[1,1][2], color='plum', lw=2, label='$cc$')
#plt.plot(sym[1,1][0], sym[1,1][2], color='purple', lw=2, ls='--')
#plt.plot(fid[1,1][0], fid[2,2][2], color='steelblue', lw=2, label='$ss$')
#plt.plot(sym[1,1][0], sym[2,2][2], color='midnightblue', lw=2, ls='--')
#plt.plot(fid[1,1][0], fid[2,1][2], color='pink', lw=2, label='$cs$')
#plt.plot(sym[1,1][0], sym[2,1][2], color='hotpink', lw=2, ls='--')
#plt.xscale('log')
#plt.yscale('log')
#plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
#plt.ylabel('Number of Pairs', fontsize=18)
#plt.legend(loc='lower right')
#plt.show()


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
sel=(sym[0,0][2]>0)
plt.plot(fid[0,0][0], fid[0,0][1], color='plum', lw=2)
plt.plot(sym[0,0][0][sym[0,0][1]>0], sym[0,0][1][sym[0,0][1]>0], color='purple', lw=2, ls='--')
#plt.errorbar(fid[1,1][0], fid[1,1][1], yerr=fid[1,1][3], elinewidth=2, linestyle='none', color='plum')
plt.errorbar(sym[0,0][0][sym[0,0][1]>0], sym[0,0][1][sym[0,0][1]>0], yerr=sym[0,0][-1][sym[0,0][1]>0], linestyle='none', color='purple')
plt.errorbar(sym[0,0][0][sym[0,0][1]<0], abs(sym[0,0][1][sym[0,0][1]<0]), yerr=sym[0,0][-1][sym[0,0][1]<0], fmt='x', linestyle='none', color='purple')
plt.errorbar(fid[0,0][0], fid[0,0][1], yerr=fid[0,0][-1], linestyle='none', color='plum')
plt.xscale('log')
#plt.yscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-7,1e0)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('ED Correlation', fontsize=18)
plt.title('All Galaxies', fontsize=20)
plt.show()
print fid[0,0][1]
print sym[0,0][1]


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.plot(fid[1,1][0], abs(fid[1,1][1]), color='plum', lw=2)
plt.plot(sym[1,1][0], abs(sym[1,1][1]), color='purple', lw=2, ls='--')
#plt.errorbar(fid[1,1][0], fid[1,1][1], yerr=fid[1,1][3], elinewidth=2, linestyle='none', color='plum')
plt.errorbar(sym[1,1][0], abs(sym[1,1][1]), yerr=sym[1,1][-1], linestyle='none', color='purple')
plt.xscale('log')
#plt.yscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-7,1e0)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('ED Correlation', fontsize=18)
plt.title('$cc$', fontsize=20)
plt.show()

print fid[1,1][2]
print fid[1,1][1]
print sym[1,1][1]




fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
sel=(sym[2,2][2]>0)
plt.plot(fid[2,2][0], abs(fid[2,2][1]), color='steelblue', lw=2, label='Unsymmetrised')
plt.plot(sym[2,2][0][sel], abs(sym[2,2][1][sel]), color='midnightblue', lw=2, ls='--', label='Symmetrised')
plt.plot(sym[2,2][0][(sym[2,2][1]<0) & sel], abs(sym[2,2][1][(sym[2,2][1]<0) & sel]), 'x', ms=8, color='midnightblue', lw=2)
plt.errorbar(fid[2,2][0], fid[2,2][1], yerr=fid[2,2][-1], linestyle='none', color='steelblue')
plt.errorbar(sym[2,2][0][sel], abs(sym[2,2][1][sel]), yerr=sym[2,2][-1][sel], linestyle='none', color='midnightblue')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-7,1e0)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('ED Correlation', fontsize=18)
plt.title('$ss$', fontsize=20)
plt.legend(loc='upper right')
plt.show()
print fid[2,2][1]
print sym[2,2][1]



fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.plot(fid[1,2][0], abs(fid[1,2][1]), color='gray', lw=2)
plt.plot(sym[1,2][0], abs(sym[1,2][1]), color='green', lw=2, ls='--')
plt.plot(sym[1,2][0][sym[1,2][1]<0], abs(sym[1,2][1][sym[1,2][1]<0]), 'x', ms=8, color='green', lw=2)
plt.errorbar(fid[1,2][0], fid[1,2][1], yerr=fid[1,2][-1], linestyle='none', color='gray')
plt.errorbar(sym[1,2][0], abs(sym[1,2][1]), yerr=sym[1,2][-1], linestyle='none', color='green')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-7,1e0)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('ED Correlation', fontsize=18)
plt.title('$cs$', fontsize=20)
plt.show()
print fid[1,2][1]
print sym[1,2][1]


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.plot(fid[2,1][0], abs(fid[2,1][1]), color='pink', lw=2)
plt.plot(sym[2,1][0], abs(sym[2,1][1]), color='hotpink', lw=2, ls='--')
plt.plot(sym[2,1][0][sym[2,1][1]<0], abs(sym[2,1][1][sym[2,1][1]<0]), 'x', ms=8, color='hotpink', lw=2)
plt.errorbar(fid[2,1][0], fid[2,1][1], yerr=fid[2,1][-1], linestyle='none', color='pink')
plt.errorbar(sym[2,1][0], abs(sym[2,1][1]), yerr=sym[2,1][-1], linestyle='none', color='hotpink')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-7,1e0)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('ED Correlation', fontsize=18)
plt.title('$sc$', fontsize=20)
plt.show()
print fid[2,1][1]
print sym[2,1][1]





fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot(fid[0,0][0], abs(fid[0,0][1]), color='plum', lw=2, label='All')
plt.errorbar(fid[0,0][0], fid[0,0][1], yerr=fid[0,0][-1], linestyle='none', color='plum')
plt.plot(fid[1,1][0], abs(fid[1,1][1]), color='purple', lw=2, label='$cc$')
plt.errorbar(fid[1,1][0], fid[1,1][1], yerr=fid[1,1][-1], linestyle='none', color='purple')
plt.plot(fid[2,2][0], abs(fid[2,2][1]), color='steelblue', lw=2, label='$ss$')
plt.errorbar(fid[2,2][0], fid[2,2][1], yerr=fid[2,2][-1], linestyle='none', color='steelblue')
plt.plot(fid[1,2][0], abs(fid[1,2][1]), color='gray', lw=2, label='$cs$')
plt.errorbar(fid[1,2][0], fid[1,2][1], yerr=fid[1,2][-1], linestyle='none', color='gray')
plt.plot(fid[2,1][0], abs(fid[2,1][1]), color='pink', lw=2, label='$sc$')
plt.errorbar(fid[2,1][0], fid[2,1][1], yerr=fid[2,1][-1], linestyle='none', color='pink')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.legend(loc='lower left')
plt.ylim(1e-7,1e0)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('ED Correlation', fontsize=18)
plt.title('$sc$', fontsize=20)
plt.show()
# Out:
# [0.16384285 0.05474949 0.02766511 0.00964621 0.00271368]
# [0.08127505 0.0448245  0.02544187 0.00913487 0.00258898]
# [0.02046139 0.00341018 0.00121369 0.00091043 0.00069596]
# [0.02934396 0.04263709 0.02598095 0.00913844 0.00254803]
# [0.02934396 0.04263709 0.02598095 0.00913844 0.00254803]
# [0.09813267 0.05646692 0.04064558 0.01179859 0.00360146]
# [0.02162577 0.03283498 0.02126681 0.00496864 0.00156219]
# [0.10067662 0.05749508 0.02120896 0.00769622 0.00218128]
# [0.08942362 0.04349516 0.00631444 0.00349512 0.00104186]
# [0.31449577 0.12215267 0.0432589  0.01543292 0.00463024]
# [0.11143997 0.06681973 0.04165484 0.01530057 0.00461861]

# %%
fid = {}
sym = {}

base = '/Users/hattifattener/Documents/ias/mbii/2pt/ns300_nd1000/v9/'
for i in xrange(2):
    for j in xrange(2):
        fid[(i+1,j+1)] = np.loadtxt(base+'EE_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/EE_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        
fid[(0,0)] = np.loadtxt(base+'EE_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
sym[(0,0)] = np.loadtxt(base+'symmetrised/EE_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T

print fid[0,0][2].sum()
print sym[0,0][2].sum()

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
sel=(sym[0,0][2]>0)
plt.plot(fid[0,0][0], fid[0,0][1], color='plum', lw=2)
plt.plot(sym[0,0][0][sym[0,0][1]>0], sym[0,0][1][sym[0,0][1]>0], color='purple', lw=2, ls='--')
#plt.errorbar(fid[1,1][0], fid[1,1][1], yerr=fid[1,1][3], elinewidth=2, linestyle='none', color='plum')
plt.errorbar(sym[0,0][0][sym[0,0][1]>0], sym[0,0][1][sym[0,0][1]>0], yerr=sym[0,0][-1][sym[0,0][1]>0], linestyle='none', color='purple')
plt.errorbar(sym[0,0][0][sym[0,0][1]<0], abs(sym[0,0][1][sym[0,0][1]<0]), yerr=sym[0,0][-1][sym[0,0][1]<0], fmt='x', linestyle='none', color='purple')
plt.errorbar(fid[0,0][0], fid[0,0][1], yerr=fid[0,0][-1], linestyle='none', color='plum')
plt.xscale('log')
#plt.yscale('log')
ax.set_yscale('log', nonposy="clip")
#plt.ylim(1e-4,1e-1)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('EE Correlation', fontsize=18)
plt.title('All Galaxies', fontsize=20)
plt.show()
print fid[0,0][1]
print sym[0,0][1]


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.plot(fid[1,1][0], abs(fid[1,1][1]), color='plum', lw=2)
plt.plot(sym[1,1][0], abs(sym[1,1][1]), color='purple', lw=2, ls='--')
#plt.errorbar(fid[1,1][0], fid[1,1][1], yerr=fid[1,1][3], elinewidth=2, linestyle='none', color='plum')
plt.errorbar(sym[1,1][0], abs(sym[1,1][1]), yerr=sym[1,1][-1], linestyle='none', color='purple')
plt.xscale('log')
#plt.yscale('log')
ax.set_yscale('log', nonposy="clip")
#plt.ylim(1e-4,1e-1)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('EE Correlation', fontsize=18)
plt.title('$cc$', fontsize=20)
plt.show()

print fid[1,1][2]
print fid[1,1][1]
print sym[1,1][1]




fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
sel=(sym[2,2][2]>0)
plt.plot(fid[2,2][0], abs(fid[2,2][1]), color='steelblue', lw=2, label='Unsymmetrised')
plt.plot(sym[2,2][0][sel], abs(sym[2,2][1][sel]), color='midnightblue', lw=2, ls='--', label='Symmetrised')
plt.plot(sym[2,2][0][(sym[2,2][1]<0) & sel], abs(sym[2,2][1][(sym[2,2][1]<0) & sel]), 'x', ms=8, color='midnightblue', lw=2)
plt.errorbar(fid[2,2][0], fid[2,2][1], yerr=fid[2,2][-1], linestyle='none', color='steelblue')
plt.errorbar(sym[2,2][0][sel], abs(sym[2,2][1][sel]), yerr=sym[2,2][-1][sel], linestyle='none', color='midnightblue')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-7,1e0)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('EE Correlation', fontsize=18)
plt.title('$ss$', fontsize=20)
plt.legend(loc='lower left')
plt.show()
print fid[2,2][1]
print sym[2,2][1]

print np.array(sym[2,2][-1])/np.array(fid[2,2][-1])



fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.plot(fid[2,1][0], abs(fid[2,1][1]), color='pink', lw=2)
plt.plot(sym[2,1][0], abs(sym[2,1][1]), color='hotpink', lw=2, ls='--')
plt.plot(sym[2,1][0][sym[2,1][1]<0], abs(sym[2,1][1][sym[2,1][1]<0]), 'x', ms=8, color='hotpink', lw=2)
plt.errorbar(fid[2,1][0], fid[2,1][1], yerr=fid[2,1][-1], linestyle='none', color='pink')
plt.errorbar(sym[2,1][0], abs(sym[2,1][1]), yerr=sym[2,1][-1], linestyle='none', color='hotpink')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-7,1e0)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('EE Correlation', fontsize=18)
plt.title('$sc$', fontsize=20)
plt.show()
print fid[2,1][1]
print sym[2,1][1]





fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot(fid[0,0][0], abs(fid[0,0][1]), color='plum', lw=2, label='All')
plt.errorbar(fid[0,0][0], fid[0,0][1], yerr=fid[0,0][-1], linestyle='none', color='plum')
plt.plot(fid[1,1][0], abs(fid[1,1][1]), color='purple', lw=2, label='$cc$')
plt.errorbar(fid[1,1][0], fid[1,1][1], yerr=fid[1,1][-1], linestyle='none', color='purple')
plt.plot(fid[2,2][0], abs(fid[2,2][1]), color='steelblue', lw=2, label='$ss$')
plt.errorbar(fid[2,2][0], fid[2,2][1], yerr=fid[2,2][-1], linestyle='none', color='steelblue')
plt.plot(fid[1,2][0], abs(fid[1,2][1]), color='gray', lw=2, label='$cs$')
plt.errorbar(fid[1,2][0], fid[1,2][1], yerr=fid[1,2][-1], linestyle='none', color='gray')
plt.plot(fid[2,1][0], abs(fid[2,1][1]), color='pink', lw=2, label='$sc$')
plt.errorbar(fid[2,1][0], fid[2,1][1], yerr=fid[2,1][-1], linestyle='none', color='pink')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.legend(loc='lower left')
plt.ylim(1e-7,1e-0)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('EE Correlation', fontsize=18)
plt.show()
# Out:
# 0.015377956687198711
# 0.012353256274346748
# [0.06318737 0.01611023 0.00339703 0.00128055 0.00014699]
# [0.01842176 0.00788435 0.00217791 0.00117779 0.0001392 ]
# [0.01842177 0.00511917 0.00129296 0.00028532 0.00012319]
# [-0.00812641  0.00982417  0.00311037  0.00147684  0.00014492]
# [-0.00812641  0.00982417  0.00311037  0.00147684  0.00014492]
# [ 2.87846497e-02  2.51954540e-02  5.49502231e-03 -1.22025044e-04
#  -1.72581315e-05]
# [ 3.59161964e-02  6.27759448e-03 -1.79325864e-05 -2.39727754e-03
#   4.10184122e-04]
# [0.94685909 1.02933796 1.13458355 1.17285607 0.82724012]
# [0.08628839 0.0320108  0.00418563 0.00057696 0.0001655 ]
# [ 2.11755129e-02  2.25930560e-03 -8.43871850e-04  2.02429681e-04
#   9.83453261e-05]

# %%
fid = {}
sym = {}

base = '/Users/hattifattener/Documents/ias/mbii/2pt/ns300_nd1000/v9/'
for i in xrange(2):
    for j in xrange(2):
        fid[(i+1,j+1)] = np.loadtxt(base+'gg_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/gg_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T

fid[(0,0)] = np.loadtxt(base+'gg_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
sym[(0,0)] = np.loadtxt(base+'symmetrised/gg_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T

plt.plot(fid[0,0][0], fid[0,0][1], color='plum', lw=2, ls='-', label='Unsymmetrised')
plt.plot(sym[0,0][0], sym[0,0][1], color='purple', lw=2, ls='--', label='Symmetrised')
plt.errorbar(sym[0,0][0], sym[0,0][1], yerr=sym[0,0][-1], color='purple', linestyle='none')
plt.xscale('log')
plt.yscale('log', nonposy='clip')
plt.ylim(1e-3, 1e2)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=20)
plt.ylabel(r'$\xi_{gg}(r)$', fontsize=20)
plt.title('All Galaxies', fontsize=20)
plt.legend()
plt.show()

plt.plot(sym[1,1][0], sym[1,1][1], color='plum', lw=2, ls='-', label='$cc$')
plt.errorbar(sym[1,1][0], sym[1,1][1], yerr=sym[2,2][-1], linestyle='none', color='plum', lw=2)
plt.plot(sym[2,1][0], sym[2,1][1], color='purple', lw=2, ls='--', label='$sc$')
plt.errorbar(sym[2,1][0], sym[2,1][1], yerr=sym[2,2][-1], linestyle='none', color='purple', lw=2)
plt.plot(sym[1,2][0], sym[1,2][1], color='green', lw=2, ls=':', label='$cs$')
plt.errorbar(sym[1,2][0], sym[1,2][1], yerr=sym[2,2][-1], linestyle='none', color='green', lw=2)
plt.plot(sym[2,2][0], sym[2,2][1], color='hotpink', lw=2, ls='--', label='$ss$')
plt.errorbar(sym[2,2][0], sym[2,2][1], yerr=sym[2,2][-1], linestyle='none', color='hotpink', lw=2)
plt.xscale('log')
plt.yscale('log', nonposy='clip')
plt.ylim(1e-3, 1e2)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=20)
plt.ylabel(r'$\xi_{gg}(r)$', fontsize=20)
plt.title('Symmetrised', fontsize=20)
plt.legend()
plt.show()

print sym[1,1][1]

plt.plot(fid[1,1][0], fid[1,1][1], color='plum', lw=2, ls='-', label='$cc$')
plt.errorbar(fid[1,1][0], sym[1,1][1], yerr=sym[2,2][-1], linestyle='none', color='plum', lw=2)
plt.plot(fid[2,1][0], fid[2,1][1], color='purple', lw=2, ls='--', label='$sc$')
plt.errorbar(fid[2,1][0], sym[2,1][1], yerr=fid[2,2][-1], linestyle='none', color='purple', lw=2)
plt.plot(fid[1,2][0], fid[1,2][1], color='green', lw=2, ls=':', label='$cs$')
plt.errorbar(sym[1,2][0], fid[1,2][1], yerr=fid[2,2][-1], linestyle='none', color='green', lw=2)
plt.plot(fid[2,2][0], fid[2,2][1], color='hotpink', lw=2, ls='--', label='$ss$')
plt.errorbar(fid[2,2][0], fid[2,2][1], yerr=fid[2,2][-1], linestyle='none', color='hotpink', lw=2)
plt.xscale('log')
plt.yscale('log', nonposy='clip')
plt.ylim(1e-3, 1e2)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=20)
plt.ylabel(r'$\xi_{gg}(r)$', fontsize=20)
plt.title('Unsymmetrised', fontsize=20)
plt.legend()
plt.show()


plt.plot(fid[1,1][0], (fid[0,0][1]-sym[0,0][1])/fid[0,0][1], color='steelblue', lw=2, ls='-', label='All')
plt.plot(fid[1,1][0], (fid[1,1][1]-sym[1,1][1])/fid[1,1][1], color='plum', lw=2, ls='-', label='$cc$')
plt.plot(fid[2,1][0], (fid[2,1][1]-sym[2,1][1])/fid[2,1][1], color='purple', lw=2, ls='--', label='$sc$')
plt.plot(fid[1,2][0], (fid[1,2][1]-sym[1,2][1])/fid[1,2][1], color='green', lw=2, ls=':', label='$cs$')
plt.plot(fid[2,2][0], (fid[2,2][1]-sym[2,2][1])/fid[2,2][1], color='hotpink', lw=2, ls='--', label='$ss$')

plt.xscale('log')
#plt.yscale('log')
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=20)
plt.ylabel(r'$\Delta \xi_{gg}(r) / \xi^\mathrm{unsym}_{gg}(r)  $', fontsize=20)
plt.title('Unsymmetrised - Symmetrised', fontsize=20)
plt.legend()
plt.show()
# Out:
# [1.27142857 7.36234177 2.57466167 0.68070114 0.16893963 0.01871618]
# /Library/Python/2.7/site-packages/ipykernel_launcher.py:66: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# ## Projected Correlation Functions

# %% [markdown]
# ### $w_{g+}(x,y)$

# %%
fid = {}
sym = {}

base = '/Users/hattifattener/Documents/ias/mbii/2pt/ns300_nd1000/v9/'
for i in xrange(2):
    for j in xrange(2):
        fid[(i+1,j+1)] = np.loadtxt(base+'GIplus_proj_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/GIplus_proj_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T

fid[(0,0)] = np.loadtxt(base+'GIplus_proj_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
sym[(0,0)] = np.loadtxt(base+'symmetrised/GIplus_proj_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.plot(fid[0,0][0], abs(fid[0,0][1]), color='plum', lw=2)
plt.plot(sym[0,0][0], abs(sym[0,0][1]), color='purple', lw=2, ls='--')
plt.errorbar(sym[0,0][0], sym[0,0][1], yerr=sym[0,0][2], linestyle='none', color='purple')
plt.errorbar(fid[0,0][0], fid[0,0][1], yerr=fid[0,0][2], linestyle='none', color='plum')
plt.xscale('log')
#plt.yscale('log')
ax.set_yscale('log', nonposy="clip")
#plt.ylim(1e-4,1e-1)
plt.xlabel('$r_\mathrm{p}$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel(r'$w_{g+}(r_\mathrm{p})$', fontsize=18)
plt.title('All Galaxies', fontsize=20)
plt.show()

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.plot(fid[1,1][0], abs(fid[1,1][1]), color='plum', lw=2)
plt.plot(sym[1,1][0], abs(sym[1,1][1]), color='purple', lw=2, ls='--')
#plt.errorbar(fid[1,1][0], fid[1,1][1], yerr=fid[1,1][3], elinewidth=2, linestyle='none', color='plum')
plt.errorbar(sym[1,1][0], sym[1,1][1], yerr=sym[1,1][2], linestyle='none', color='purple')
plt.xscale('log')
#plt.yscale('log')
ax.set_yscale('log', nonposy="clip")
#plt.ylim(1e-4,1e-1)
plt.xlabel('$r_\mathrm{p}$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel(r'$w_{g+}(r_\mathrm{p})$', fontsize=18)
plt.title('$cc$', fontsize=20)
plt.show()
print fid[1,1][1]
print sym[1,1][1]


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.plot(fid[2,2][0], abs(fid[2,2][1]), color='steelblue', lw=2)
plt.plot(sym[2,2][0], abs(sym[2,2][1]), color='midnightblue', lw=2, ls='--')
plt.errorbar(fid[2,2][0], fid[2,2][1], yerr=fid[2,2][2], linestyle='none', color='steelblue')
plt.errorbar(sym[2,2][0], sym[2,2][1], yerr=sym[2,2][2], linestyle='none', color='midnightblue')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.xlabel('$r_\mathrm{p}$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel(r'$w_{g+}(r_\mathrm{p})$', fontsize=18)
plt.title('$ss$', fontsize=20)
plt.show()


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.plot(fid[1,2][0], abs(fid[1,2][1]), color='gray', lw=2)
plt.plot(sym[1,2][0], abs(sym[1,2][1]), color='green', lw=2, ls='--')
plt.errorbar(fid[1,2][0], fid[1,2][1], yerr=fid[1,2][2], linestyle='none', color='gray')
plt.errorbar(sym[1,2][0], sym[1,2][1], yerr=sym[1,2][2], linestyle='none', color='green')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.xlabel('$r_\mathrm{p}$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel(r'$w_{g+}(r_\mathrm{p})$', fontsize=18)
plt.title('$cs$', fontsize=20)
plt.show()


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.plot(fid[2,1][0], abs(fid[2,1][1]), color='pink', lw=2)
plt.plot(sym[2,1][0], abs(sym[2,1][1]), color='hotpink', lw=2, ls='--')
plt.errorbar(fid[2,1][0], fid[2,1][1], yerr=fid[2,1][2], linestyle='none', color='pink')
plt.errorbar(sym[2,1][0], sym[2,1][1], yerr=sym[2,1][2], linestyle='none', color='hotpink')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.xlabel('$r_\mathrm{p}$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel(r'$w_{g+}(r_\mathrm{p})$', fontsize=18)
plt.title('$sc$', fontsize=20)
plt.show()

print fid[2,1][1]
print fid[1,2][1]
# Out:
# [0.031405   0.04426468 0.01017902 0.00214345 0.00050302]
# [0.031405   0.04426468 0.01017902 0.00214345 0.00050302]
# [4.80667064e+00 2.70945565e-01 2.09488183e-02 2.75550497e-03
#  8.70598406e-04]
# [1.03174062e+00 1.02021317e-01 1.15377444e-02 1.21946323e-04
#  1.00919383e-04]

# %%
ed_fid = {}
ed_sym = {}
ee_fid = {}
ee_sym = {}
gg_fid = {}
gg_sym = {}
wgp_fid = {}
wgp_sym = {}

base = '/Users/hattifattener/Documents/ias/mbii/2pt/ns300_nd1000/v9/'
for i in xrange(2):
    for j in xrange(2):
        ed_fid[(i+1,j+1)] = np.loadtxt(base+'ED_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        ed_sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/ED_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        ee_fid[(i+1,j+1)] = np.loadtxt(base+'EE_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        ee_sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/EE_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        gg_fid[(i+1,j+1)] = np.loadtxt(base+'gg_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        gg_sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/gg_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        wgp_fid[(i+1,j+1)] = np.loadtxt(base+'GIplus_proj_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        wgp_sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/GIplus_proj_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        
ee_fid[(0,0)] = np.loadtxt(base+'EE_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
ee_sym[(0,0)] = np.loadtxt(base+'symmetrised/EE_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T        
ed_fid[(0,0)] = np.loadtxt(base+'ED_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
ed_sym[(0,0)] = np.loadtxt(base+'symmetrised/ED_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
gg_fid[(0,0)] = np.loadtxt(base+'gg_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
gg_sym[(0,0)] = np.loadtxt(base+'symmetrised/gg_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
wgp_fid[(0,0)] = np.loadtxt(base+'GIplus_proj_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
wgp_sym[(0,0)] = np.loadtxt(base+'symmetrised/GIplus_proj_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
dee = (ee_sym[0,0][1] - ee_fid[0,0][1])/ee_fid[0,0][1]
plt.plot(ee_fid[0,0][0], dee, color='purple', ls='--', label='EE', lw=2)
ded = (ed_sym[0,0][1] - ed_fid[0,0][1])/ed_fid[0,0][1]
plt.plot(ed_fid[0,0][0], ded, color='royalblue', ls=':', label='ED', lw=2)
dwgp = (wgp_sym[0,0][1] - wgp_fid[0,0][1])/wgp_fid[0,0][1]
plt.plot(wgp_fid[0,0][0], dwgp, color='hotpink', ls='-.', label='$w_{g+}$', lw=2)
dgg = (gg_sym[0,0][1] - gg_fid[0,0][1])/gg_fid[0,0][1]
plt.plot(gg_fid[0,0][0], dgg, color='orange', ls='-',label='gg', lw=2)
plt.legend(loc='lower right')
plt.xscale('log')
plt.axhline(0,color='k',ls=':')
#ax.set_yscale('log', nonposy="clip")
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel(r'$(\xi^\mathrm{sym}-\xi^\mathrm{unsym})/\xi^\mathrm{unsym}$', fontsize=20)
plt.title('All Galaxies', fontsize=20)
plt.xlim(0.05,33)
plt.show()

# %% [markdown]
# ## Catalogue level tests

# %%
import fitsio as fi


# Read in the catalogues from coma
base = '/Users/hattifattener/Documents/ias/mbii/2pt/ns300_nd1000/v6/'
fid = fi.FITS('/Users/hattifattener/Documents/ias/mbii/cats/base_subhalo_shapes-v9-ndm1000-nst300.fits')[-1].read()
sym = fi.FITS('/Users/hattifattener/Documents/ias/mbii/cats/base_subhalo_shapes-v9-ndm1000-nst300-symmetrised-testing0.fits')[-1].read()
print fid.size
# Out:
# 33880

# %%
central_name='most_massive'
print 'Subhalo catalogues are equal in length :', (fid.size==sym.size)
print 'Central flags are rotationally invariant :', (fid[central_name]==sym[central_name]).all()

ids = np.unique(fid['halo_id'])
ncent = [len(fid[(fid[central_name]==1) & (fid['halo_id']==hi) ]) for hi in ids]
ncent = np.array(ncent)
# Out:
# Subhalo catalogues are equal in length : True
# Central flags are rotationally invariant : True

# %%
print 'Maximum no. of centrals per halo :', ncent.max()
print 'Minimum no. of centrals per halo :', ncent.min()
print 'Global satellite fraction : %d/%d (%3.3f percent)'%(fid[(fid[central_name]!=1)].size, fid.size, 100*(1 - fid[(fid[central_name]==1)].size*1.0/fid.size)  )
# Out:
# Maximum no. of centrals per halo : 1
# Minimum no. of centrals per halo : 0
# Global satellite fraction : 3363/33880 (9.926 percent)

# %%
cmask = (fid['most_massive']==1)
print 'All subhalos'
print 'Mean e1 : %3.4f +- %3.4f'%(fid['e1'].mean(), fid['e1'].std()/np.sqrt(fid['e1'].size) )
print 'Mean e2 : %3.4f +- %3.4f'%(fid['e2'].mean(), fid['e2'].std()/np.sqrt(fid['e2'].size) )

print 'Mean e1 (symmetrised) : %3.4f +- %3.4f'%(sym['e1'].mean(), sym['e1'].std()/np.sqrt(sym['e1'].size) )
print 'Mean e2 (symmetrised) : %3.4f +- %3.4f'%(sym['e2'].mean(), sym['e2'].std()/np.sqrt(sym['e2'].size) )

print ''
print 'Satellites'
print 'Mean e1 : %3.4f +- %3.4f'%(fid['e1'][np.invert(cmask)].mean(), fid['e1'][np.invert(cmask)].std()/np.sqrt(fid['e1'][np.invert(cmask)].size) )
print 'Mean e2 : %3.4f +- %3.4f'%(fid['e2'][np.invert(cmask)].mean(), fid['e2'][np.invert(cmask)].std()/np.sqrt(fid['e2'][np.invert(cmask)].size) )

print 'Mean e1 (symmetrised) : %3.4f +- %3.4f'%(sym['e1'][np.invert(cmask)].mean(), sym['e1'][np.invert(cmask)].std()/np.sqrt(sym['e1'][np.invert(cmask)].size) )
print 'Mean e2 (symmetrised) : %3.4f +- %3.4f'%(sym['e2'][np.invert(cmask)].mean(), sym['e2'][np.invert(cmask)].std()/np.sqrt(sym['e2'][np.invert(cmask)].size) ) 

print ''
print 'Centrals'
print 'Mean e1 : %3.4f +- %3.4f'%(fid['e1'][cmask].mean(), fid['e1'][cmask].std()/np.sqrt(fid[cmask]['e1'].size) )
print 'Mean e2 : %3.4f +- %3.4f'%(fid['e2'][cmask].mean(), fid['e2'][cmask].std()/np.sqrt(fid[cmask]['e2'].size) )

print 'Mean e1 (symmetrised) : %3.4f +- %3.4f'%(sym['e1'][cmask].mean(), sym['e1'][cmask].std()/np.sqrt(sym['e1'][cmask].size) )
print 'Mean e2 (symmetrised) : %3.4f +- %3.4f'%(sym['e2'][cmask].mean(), sym['e2'][cmask].std()/np.sqrt(sym['e2'][cmask].size) )
# Out:
# All subhalos
# Mean e1 : 0.0013 +- 0.0009
# Mean e2 : 0.0009 +- 0.0009
# Mean e1 (symmetrised) : 0.0013 +- 0.0009
# Mean e2 (symmetrised) : 0.0004 +- 0.0009
#
# Satellites
# Mean e1 : 0.0041 +- 0.0026
# Mean e2 : 0.0012 +- 0.0025
# Mean e1 (symmetrised) : 0.0046 +- 0.0027
# Mean e2 (symmetrised) : -0.0036 +- 0.0026
#
# Centrals
# Mean e1 : 0.0010 +- 0.0010
# Mean e2 : 0.0008 +- 0.0009
# Mean e1 (symmetrised) : 0.0010 +- 0.0010
# Mean e2 (symmetrised) : 0.0008 +- 0.0009

# %%
cmask = (fid['most_massive']==1)
# Plot the ellipticity distributions
# ellipticity magnitude

Hc,cbins = np.histogram(np.sqrt(fid['e1'][cmask]**2+fid['e2'][cmask]**2), bins=60, normed=1)
Hc_sym, cbins_sym = np.histogram(np.sqrt(sym['e1'][cmask]**2+sym['e2'][cmask]**2), bins=60, normed=1)
Hs, sbins = np.histogram(np.sqrt(fid['e1'][np.invert(cmask)]**2+fid['e2'][np.invert(cmask)]**2), bins=60, normed=1)
Hs_sym, sbins_sym = np.histogram(np.sqrt(sym['e1'][np.invert(cmask)]**2+sym['e2'][np.invert(cmask)]**2), bins=60, normed=1)

x = (cbins[:-1]+cbins[1:])/2
#plt.title("This shouldn't change under rotation")
plt.close()
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(fontsize=12)
plt.xlim(0,0.98)
plt.ylim(ymin=0)
plt.xlabel('$|e|$', fontsize=20)
plt.subplots_adjust(top=0.98,bottom=0.14)
plt.savefig('/Users/hattifattener/Documents/ias/mbii/figures/ellipticity-spiltby_most_massive-symmetrised.pdf')
plt.show()


# e1
Hc,cbins = np.histogram(fid['e1'][cmask], bins=60, normed=1)
Hc_sym, cbins_sym = np.histogram(sym['e1'][cmask], bins=60, normed=1)
Hs, sbins = np.histogram(fid['e1'][np.invert(cmask)], bins=60, normed=1)
Hs_sym, sbins_sym = np.histogram(sym['e1'][np.invert(cmask)], bins=60, normed=1)

x = (cbins[:-1]+cbins[1:])/2
plt.close()
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(fontsize=12)
plt.xlim(-1,1.6)
plt.ylim(ymin=0)
plt.xlabel('$e_1$', fontsize=20)
plt.subplots_adjust(top=0.98,bottom=0.14)
plt.savefig('/Users/hattifattener/Documents/ias/mbii/figures/e1-spiltby_most_massive-symmetrised.pdf')
plt.show()

# e2
Hc,cbins = np.histogram(fid['e2'][cmask], bins=60, normed=1)
Hc_sym, cbins_sym = np.histogram(sym['e2'][cmask], bins=60, normed=1)
Hs, sbins = np.histogram(fid['e2'][np.invert(cmask)], bins=60, normed=1)
Hs_sym, sbins_sym = np.histogram(sym['e2'][np.invert(cmask)], bins=60, normed=1)

x = (cbins[:-1]+cbins[1:])/2
plt.close()
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(fontsize=12)
plt.xlim(-1,2)
plt.ylim(ymin=0)
plt.xlabel('$e_2$', fontsize=20)
plt.subplots_adjust(top=0.98,bottom=0.14)
plt.savefig('/Users/hattifattener/Documents/ias/mbii/figures/e2-spiltby_most_massive-symmetrised.pdf')
plt.show()

e_cfid = np.sqrt(fid['e1'][cmask]**2+fid['e2'][cmask]**2)
e_sfid = np.sqrt(fid['e1'][np.invert(cmask)]**2+fid['e2'][np.invert(cmask)]**2)
e_csym = np.sqrt(sym['e1'][cmask]**2+sym['e2'][cmask]**2)
e_ssym = np.sqrt(sym['e1'][np.invert(cmask)]**2+sym['e2'][np.invert(cmask)]**2)
q_cfid = (1-e_cfid)/(1+e_cfid)
q_sfid = (1-e_sfid)/(1+e_sfid)
q_csym = (1-e_csym)/(1+e_csym)
q_ssym = (1-e_ssym)/(1+e_ssym)

Hc,cbins = np.histogram(q_cfid, bins=60, normed=1)
Hc_sym, cbins_sym = np.histogram(q_csym, bins=60, normed=1)
Hs, sbins = np.histogram(q_sfid, bins=60, normed=1)
Hs_sym, sbins_sym = np.histogram(q_ssym, bins=60, normed=1)

x = (cbins[:-1]+cbins[1:])/2
plt.close()
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(loc='upper left', fontsize=12)
plt.xlim(0,1)
plt.ylim(0,4.5)
plt.xlabel('Axis Ratio $q$', fontsize=20)
plt.subplots_adjust(top=0.98,bottom=0.14)
plt.savefig('/Users/hattifattener/Documents/ias/mbii/figures/q2d-spiltby_most_massive-symmetrised.pdf')
plt.show()

# %%
# The same as above, but for dark matter
# ellipticity magnitude

Hc,cbins = np.histogram(np.sqrt(fid['e1_dm'][cmask]**2+fid['e2_dm'][cmask]**2), bins=60, normed=1)
Hc_sym, cbins_sym = np.histogram(np.sqrt(sym['e1_dm'][cmask]**2+sym['e2_dm'][cmask]**2), bins=60, normed=1)
Hs, sbins = np.histogram(np.sqrt(fid['e1_dm'][np.invert(cmask)]**2+fid['e2_dm'][np.invert(cmask)]**2), bins=60, normed=1)
Hs_sym, sbins_sym = np.histogram(np.sqrt(sym['e1_dm'][np.invert(cmask)]**2+sym['e2_dm'][np.invert(cmask)]**2), bins=60, normed=1)

x = (cbins[:-1]+cbins[1:])/2
#plt.title("This shouldn't change under rotation")
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(fontsize=12)
plt.xlim(0,0.98)
plt.xlabel('$|e|$', fontsize=20)
plt.show()


# e1
Hc,cbins = np.histogram(fid['e1_dm'][cmask], bins=60, normed=1)
Hc_sym, cbins_sym = np.histogram(sym['e1_dm'][cmask], bins=60, normed=1)
Hs, sbins = np.histogram(fid['e1_dm'][np.invert(cmask)], bins=60, normed=1)
Hs_sym, sbins_sym = np.histogram(sym['e1_dm'][np.invert(cmask)], bins=60, normed=1)

x = (cbins[:-1]+cbins[1:])/2
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(fontsize=12)
plt.xlim(-1,1.6)
plt.xlabel('$e_1$', fontsize=20)
plt.show()

# e2
Hc,cbins = np.histogram(fid['e2_dm'][cmask], bins=60, normed=1)
Hc_sym, cbins_sym = np.histogram(sym['e2_dm'][cmask], bins=60, normed=1)
Hs, sbins = np.histogram(fid['e2_dm'][np.invert(cmask)], bins=60, normed=1)
Hs_sym, sbins_sym = np.histogram(sym['e2_dm'][np.invert(cmask)], bins=60, normed=1)

x = (cbins[:-1]+cbins[1:])/2
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(fontsize=12)
plt.xlim(-1,2)
plt.xlabel('$e_2$', fontsize=20)
plt.show()


e_cfid = np.sqrt(fid['e1_dm'][cmask]**2+fid['e2_dm'][cmask]**2)
e_sfid = np.sqrt(fid['e1_dm'][np.invert(cmask)]**2+fid['e2_dm'][np.invert(cmask)]**2)
e_csym = np.sqrt(sym['e1_dm'][cmask]**2+sym['e2_dm'][cmask]**2)
e_ssym = np.sqrt(sym['e1_dm'][np.invert(cmask)]**2+sym['e2_dm'][np.invert(cmask)]**2)
q_cfid = (1-e_cfid)/(1+e_cfid)
q_sfid = (1-e_sfid)/(1+e_sfid)
q_csym = (1-e_csym)/(1+e_csym)
q_ssym = (1-e_ssym)/(1+e_ssym)

Hc,cbins = np.histogram(q_cfid, bins=60, normed=1)
Hc_sym, cbins_sym = np.histogram(q_csym, bins=60, normed=1)
Hs, sbins = np.histogram(q_sfid, bins=60, normed=1)
Hs_sym, sbins_sym = np.histogram(q_ssym, bins=60, normed=1)

x = (cbins[:-1]+cbins[1:])/2
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(loc='upper left', fontsize=12)
plt.xlim(0,1)
plt.ylim(0,4.5)
plt.xlabel('Axis Ratio $q$', fontsize=20)
plt.show()

# %%
# Now plot out some histograms of subhalo positions on the halo spheres

x0 = sym['x0']
y0 = sym['y0']
z0 = sym['z0']
xhalo = fid['x']-x0
yhalo = fid['y']-y0
zhalo = fid['z']-z0
R = np.sqrt(xhalo*xhalo+yhalo*yhalo+zhalo*zhalo)

xhalo_sym = sym['x']-x0
yhalo_sym = sym['y']-y0
zhalo_sym = sym['z']-z0
R_sym = np.sqrt(xhalo_sym*xhalo_sym+yhalo_sym*yhalo_sym+zhalo_sym*zhalo_sym)

phi = np.arccos(zhalo/R) 
theta = np.arctan2(yhalo,xhalo)

print (zhalo/R_sym).min()

phi_sym = np.arccos(zhalo_sym/R_sym)
theta_sym = np.arctan2(yhalo_sym,xhalo_sym)


Hc,cbins = np.histogram(phi[cmask]/np.pi, bins=np.linspace(-2,2,80), normed=1)
Hc_sym, cbins_sym = np.histogram(phi_sym[cmask]/np.pi, bins=np.linspace(-2,2,80), normed=1)
Hs, sbins = np.histogram(phi[np.invert(cmask)]/np.pi, bins=np.linspace(-2,2,80), normed=1)
Hs_sym, sbins_sym = np.histogram(phi_sym[np.invert(cmask)]/np.pi, bins=np.linspace(-2,2,80), normed=1)

x = (cbins[:-1]+cbins[1:])/2
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(loc='upper left', fontsize=12)
plt.xlim(-1.5,1.5)
plt.xlabel(r'Position Angle $\phi$ / $\pi$ radians', fontsize=20)
plt.show()

Hc,cbins = np.histogram(theta[cmask]/np.pi, bins=np.linspace(-2,2,50), normed=1)
Hc_sym, cbins_sym = np.histogram(theta_sym[cmask]/np.pi, bins=np.linspace(-2,2,50), normed=1)
Hs, sbins = np.histogram(theta[np.invert(cmask)]/np.pi, bins=np.linspace(-2,2,50), normed=1)
Hs_sym, sbins_sym = np.histogram(theta_sym[np.invert(cmask)]/np.pi, bins=np.linspace(-2,2,50), normed=1)

x = (cbins[:-1]+cbins[1:])/2
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(loc='lower center', fontsize=12)
plt.xlabel(r'Position Angle $\theta$ / $\pi$ radians', fontsize=20)
plt.xlim(-1.5,1.5)
plt.show()




Hc,cbins = np.histogram(xhalo[cmask], bins=np.linspace(-0.2,0.15,80), normed=1)
Hc_sym, cbins_sym = np.histogram(xhalo_sym[cmask], bins=np.linspace(-0.2,0.15,80), normed=1)
Hs, sbins = np.histogram(xhalo[np.invert(cmask)], bins=np.linspace(-0.2,0.15,80), normed=1)
Hs_sym, sbins_sym = np.histogram(xhalo_sym[np.invert(cmask)], bins=np.linspace(-0.2,0.15,80), normed=1)

x = (cbins[:-1]+cbins[1:])/2
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(loc='upper left', fontsize=12)
plt.xlim(-0.2,0.1)
plt.xlabel(r'Halo Frame Position $x$ / Mpc', fontsize=20)
plt.show()

Hc,cbins = np.histogram(yhalo[cmask], bins=np.linspace(-0.2,0.15,80), normed=1)
Hc_sym, cbins_sym = np.histogram(yhalo_sym[cmask], bins=np.linspace(-0.2,0.15,80), normed=1)
Hs, sbins = np.histogram(yhalo[np.invert(cmask)], bins=np.linspace(-0.2,0.15,80), normed=1)
Hs_sym, sbins_sym = np.histogram(yhalo_sym[np.invert(cmask)], bins=np.linspace(-0.2,0.15,80), normed=1)

x = (cbins[:-1]+cbins[1:])/2
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(loc='upper left', fontsize=12)
plt.xlabel(r'Halo Frame Position $y$ / Mpc', fontsize=20)
plt.xlim(-0.2,0.1)
plt.show()

Hc,cbins = np.histogram(zhalo[cmask], bins=np.linspace(-0.2,0.15,80), normed=1)
Hc_sym, cbins_sym = np.histogram(zhalo_sym[cmask], bins=np.linspace(-0.2,0.15,80), normed=1)
Hs, sbins = np.histogram(zhalo[np.invert(cmask)], bins=np.linspace(-0.2,0.15,80), normed=1)
Hs_sym, sbins_sym = np.histogram(zhalo_sym[np.invert(cmask)], bins=np.linspace(-0.2,0.15,80), normed=1)

x = (cbins[:-1]+cbins[1:])/2
plt.plot((cbins[:-1]+cbins[1:])/2, Hc, color='pink', lw=2, label='Centrals, unsymmetrised')
plt.plot((cbins_sym[:-1]+cbins_sym[1:])/2, Hc_sym, color='hotpink', lw=2, ls='--', label='Centrals, symmetrised')
plt.plot((sbins[:-1]+sbins[1:])/2, Hs, color='plum', lw=2, label='Satellites, unsymmetrised')
plt.plot((sbins_sym[:-1]+sbins_sym[1:])/2, Hs_sym, color='purple', lw=2, ls='--', label='Satellites, symmetrised')
plt.legend(loc='upper left', fontsize=12)
plt.xlabel(r'Halo Frame Position $z$ / Mpc', fontsize=20)
plt.xlim(-0.2,0.1)
plt.show()
# Out:
# -0.9997922662337402

# %%
select = (fid['halo_id']==0)
plt.subplot(111, aspect='equal')
plt.quiver(fid['x'][select], fid['y'][select], fid['a1'][select], fid['a2'][select], color='purple', width=0.004, headwidth=0.005)
plt.plot(fid['x'][select & cmask], fid['y'][select & cmask], '+', color='hotpink')
x0=fid['x'][select].mean()
y0=fid['y'][select].mean()
plt.plot(x0, y0, 'x', color='g')
plt.ylim(y0-5, y0+5)
plt.xlim(x0-5, x0+5)
plt.xlabel('x / $h^{-1}$ Mpc ', fontsize=20)
plt.ylabel('y / $h^{-1}$ Mpc ', fontsize=20)

plt.show()

select = (fid['halo_id']==0)
plt.subplot(111, aspect='equal')
plt.quiver(sym['x'][select], sym['y'][select], sym['a1'][select], sym['a2'][select], color='purple', width=0.004, headwidth=0.005)
plt.plot(sym['x'][select & cmask], fid['y'][select & cmask], '+', color='hotpink')
plt.plot(x0, y0, 'x', color='g')
plt.ylim(y0-5, y0+5)
plt.xlim(x0-5, x0+5)
plt.xlabel('x / $h^{-1}$ Mpc', fontsize=20)
plt.ylabel('y / $h^{-1}$ Mpc', fontsize=20)

plt.show()

# %%
select = (fid['halo_id']==1)
plt.subplot(111, aspect='equal')
plt.quiver(fid['x'][select], fid['y'][select], fid['a1'][select], fid['a2'][select], color='purple', width=0.004, headwidth=0.005)
plt.plot(fid['x'][select & cmask], fid['y'][select & cmask], '+', color='hotpink')
x0=fid['x'][select].mean()
y0=fid['y'][select].mean()
plt.plot(x0, y0, 'x', color='g')
plt.ylim(y0-5, y0+5)
plt.xlim(x0-5, x0+5)

plt.show()

select = (fid['halo_id']==1)
plt.subplot(111, aspect='equal')
plt.quiver(sym['x'][select], sym['y'][select], sym['a1'][select], sym['a2'][select], color='purple', width=0.004, headwidth=0.005)
plt.plot(sym['x'][select & cmask], fid['y'][select & cmask], '+', color='hotpink')
plt.plot(x0, y0, 'x', color='g')
plt.ylim(y0-5, y0+5)
plt.xlim(x0-5, x0+5)

plt.show()

# %%
print fid.dtype.names
R = fid['vrot']/fid['sigma']
Mm = fid['matter_mass']

plt.hist2d(np.log10(Mm),R,bins=100, range=((-0.5,4.),(1.,2.25)), cmap='jet')
plt.ylabel('$V_\mathrm{circ}/\sigma$', fontsize=18)
plt.xlabel('DM Mass $M_\mathrm{m}$ / $h^{-3} M_*$', fontsize=18)
plt.title('All Galaxies', fontsize=20)
plt.show()

plt.hist2d(np.log10(Mm[cmask]),R[cmask],bins=100, range=((-0.5,4.),(1.,2.25)), cmap='jet')
plt.ylabel('$V_\mathrm{circ}/\sigma$', fontsize=18)
plt.xlabel('DM Mass $M_\mathrm{m}$ / $h^{-3} M_*$', fontsize=18)
plt.title('Centrals', fontsize=20)
plt.show()

plt.hist2d(np.log10(Mm[np.invert(cmask)]),R[np.invert(cmask)],bins=100, range=((-0.5,4.),(1.,2.25)), cmap='jet')
plt.ylabel('$V_\mathrm{circ}/\sigma$', fontsize=18)
plt.xlabel('DM Mass $M_\mathrm{m}$ / $h^{-3} M_*$', fontsize=18)
plt.title('Satellites', fontsize=20)
plt.subplots_adjust(hspace=0)
plt.show()

print '---------------------------------'
Mb = fid['stellar_mass']+fid['gas_mass']

plt.hist2d(np.log10(Mb),R,bins=100, range=((-1.5,2.),(1.,2.25)), cmap='jet')
plt.ylabel('$V_\mathrm{circ}/\sigma$', fontsize=18)
plt.xlabel('Baryon Mass $M_\mathrm{b}$ / $h^{-3} M_*$', fontsize=18)
plt.title('All Galaxies', fontsize=20)
plt.show()

plt.hist2d(np.log10(Mb[cmask]),R[cmask],bins=100, range=((-1.5,2.),(1.,2.25)), cmap='jet')
plt.ylabel('$V_\mathrm{circ}/\sigma$', fontsize=18)
plt.xlabel('Baryon Mass $M_\mathrm{b}$ / $h^{-3} M_*$', fontsize=18)
plt.title('Centrals', fontsize=20)
plt.show()

plt.hist2d(np.log10(Mb[np.invert(cmask)]),R[np.invert(cmask)],bins=100, range=((-1.5,2.),(1.,2.25)), cmap='jet')
plt.ylabel('$V_\mathrm{circ}/\sigma$', fontsize=18)
plt.xlabel('Baryon Mass $M_\mathrm{b}$ / $h^{-3} M_*$', fontsize=18)
plt.title('Satellites', fontsize=20)
plt.subplots_adjust(hspace=0)
plt.show()
# Out:
# ('object_id', 'gas_mass', 'matter_mass', 'stellar_mass', 'npart_dm', 'npart_baryon', 'e1', 'e2', 'a1', 'a2', 'a3', 'b1', 'b2', 'b3', 'c1', 'c2', 'c3', 'lambda_a', 'lambda_b', 'lambda_c', 'lambda_a_proj', 'lambda_b_proj', 'e1_dm', 'e2_dm', 'a1_dm', 'a2_dm', 'a3_dm', 'b1_dm', 'b2_dm', 'b3_dm', 'c1_dm', 'c2_dm', 'c3_dm', 'lambda_a_dm', 'lambda_b_dm', 'lambda_c_dm', 'lambda_a_proj_dm', 'lambda_b_proj_dm', 'x', 'y', 'z', 'vrot', 'sigma', 'central', 'rh', 'most_massive', 'spatial_central', 'halo_id', 'nocc')
# ---------------------------------

# %%
ids = np.unique(fid['halo_id'])
nsat = np.array([len(fid[(fid[central_name]!=1) & (fid['halo_id']==hi) ]) for hi in ids])
ngal = np.array([fid['nocc'][(fid['halo_id']==hi)][0]  for hi in ids])
Mm = np.array([fid['matter_mass'][(fid['halo_id']==hi)].sum()  for hi in ids])
Mb = np.array([fid['stellar_mass'][(fid['halo_id']==hi)].sum()  for hi in ids])
Np = np.array([fid['npart_dm'][(fid['halo_id']==hi)].sum()  for hi in ids])

print 'Maximum no. of satellites: %d'%nsat.max()
print 'Minimum no. of satellites: %d'%nsat.min()
# Out:
# Maximum no. of satellites: 16
# Minimum no. of satellites: 0

# %%
Np_gal = np.array([np.median(fid['npart_dm'][(fid['halo_id']==hi)])  for hi in ids])
Npb_gal = np.array([np.median(fid['npart_baryon'][(fid['halo_id']==hi)])  for hi in ids])

# %%
print Np_gal.min(), Np_gal.max(), np.log10(np.median(Np_gal))
# Out:
# 1016.0 3551209.5 4.0849157170662025

# %%
colours=['purple', 'pink', 'plum', 'hotpink', 'green', 'steelblue', 'midnightblue']
print np.log10(Mb).min(), np.log10(Mb).max()


for i, ns in enumerate(np.unique(nsat)[:7]):
    H,x = np.histogram(np.log10(Mb[nsat==ns]), range=(-4,3), bins=80, normed=1 )
    x0 = (x[:-1]+x[1:])/2
    plt.plot(x0, H, color=colours[i], ls='-', lw=2, label='$n_\mathrm{sat}=%d$'%ns)

plt.xlabel(r'$\log(M_\mathrm{b}$  / $10^{10} M_* )$', fontsize=18)
plt.legend(loc='upper left')
plt.show()

for i, ns in enumerate(np.unique(nsat)[:7]):
    H,x = np.histogram(np.log10(Mm[nsat==ns]), range=(-1.5,5), bins=80, normed=1 )
    x0 = (x[:-1]+x[1:])/2
    plt.plot(x0, H, color=colours[i], ls='-', lw=2, label='$n_\mathrm{sat}=%d$'%ns)

plt.xlabel(r'$\log(M_\mathrm{m}$  / $10^{10} M_* )$', fontsize=18)
plt.legend(loc='upper left')
plt.show() 

for i, ns in enumerate(np.unique(nsat)[:7]):
    H,x = np.histogram(np.log10(Np[nsat==ns]), range=(3,6), bins=80, normed=1 )
    x0 = (x[:-1]+x[1:])/2
    plt.plot(x0, H, color=colours[i], ls='-', lw=2, label='$n_\mathrm{sat}=%d$'%ns)

plt.xlabel('$\log(N^\mathrm{halo}_\mathrm{p,DM})$', fontsize=18)
plt.legend(loc='upper left')
plt.show()

#for i, ns in enumerate(np.unique(nsat)[:7]):
#    H,x = np.histogram(Np_gal[nsat==ns], range=(300,5000), bins=80, normed=1 )
#    x0 = (x[:-1]+x[1:])/2
#    plt.plot(x0, H, color=colours[i], ls='-', lw=2, label='$n_\mathrm{sat}=%d$'%ns)

H,x = np.histogram(np.log10(Np_gal), range=(3,6.5), bins=80, normed=1 )
x0 = (x[:-1]+x[1:])/2
plt.plot(x0, H, color='purple', ls='-', lw=2, label='All')
H,x = np.histogram(np.log10(Np_gal[nsat==0]), range=(3,6.5), bins=80, normed=1 )
x0 = (x[:-1]+x[1:])/2
plt.plot(x0, H, color='pink', ls='-', lw=2, label='$n_\mathrm{s}=0$')

H,x = np.histogram(np.log10(Np_gal[nsat!=0]), range=(3,6.5), bins=80, normed=1 )
x0 = (x[:-1]+x[1:])/2
plt.plot(x0, H, color='hotpink', ls='-', lw=2, label='$n_\mathrm{s}>0$')

plt.xlabel('$\log(N^\mathrm{gal}_\mathrm{p,DM})$', fontsize=18)
plt.legend(loc='upper right')
plt.show()

print fid.dtype.names
# Out:
# -1.476378487308467 3.0093581616256504
# ('object_id', 'gas_mass', 'matter_mass', 'stellar_mass', 'npart_dm', 'npart_baryon', 'e1', 'e2', 'a1', 'a2', 'a3', 'b1', 'b2', 'b3', 'c1', 'c2', 'c3', 'lambda_a', 'lambda_b', 'lambda_c', 'lambda_a_proj', 'lambda_b_proj', 'e1_dm', 'e2_dm', 'a1_dm', 'a2_dm', 'a3_dm', 'b1_dm', 'b2_dm', 'b3_dm', 'c1_dm', 'c2_dm', 'c3_dm', 'lambda_a_dm', 'lambda_b_dm', 'lambda_c_dm', 'lambda_a_proj_dm', 'lambda_b_proj_dm', 'x', 'y', 'z', 'vrot', 'sigma', 'central', 'rh', 'most_massive', 'spatial_central', 'halo_id', 'nocc')

# %%
nhalos=[len(nsat[nsat==ns]) for ns in np.unique(nsat)]
Ns=np.unique(nsat)

# %%
plt.plot(Ns, nhalos, color='purple', lw=2)
plt.yscale('log')
plt.xlabel('Satellite Number $n_\mathrm{sat}$', fontsize=18)
plt.ylabel('Number of halos', fontsize=18)
plt.show()

# %%
Ntot = fid.size
print 'No. of single occupancy halos : %d/%d (%3.3f percent)'%(fid['x'][fid['nocc']==1].size, Ntot, 100.*fid['x'][fid['nocc']==1].size/Ntot)
# Out:
# No. of single occupancy halos : 28269/33880 (83.439 percent)

# %%
Hc, bc = np.histogram(sym['rh'][cmask], bins=90, range=(0,0.5), normed=1)
Hs, bs = np.histogram(sym['rh'][np.invert(cmask)], bins=90, range=(0,0.5), normed=1)
H0, b0 = np.histogram(sym['rh'], bins=90, range=(0,0.5), normed=1)

xc = (bc[:-1]+bc[1:])/2
xs = (bs[:-1]+bs[1:])/2
x0 = (b0[:-1]+b0[1:])/2

print sym['rh'][np.invert(cmask)].min(), sym['rh'][np.invert(cmask)].max(), np.median(sym['rh'][np.invert(cmask)])

plt.fill_between(xc, Hc, alpha=0.2, color='pink')
plt.plot(xc, Hc, color='hotpink', label='Centrals')
plt.fill_between(xs, Hs, alpha=0.2, color='royalblue')
plt.plot(xs, Hs, color='royalblue', label='Satellites')
plt.plot(x0, H0, lw=2, color='purple', label='All Galaxies')
plt.xlabel('Galaxy Offset $r_\mathrm{g}$ / $h^{-1}$ Mpc', fontsize=18)
plt.legend()
plt.ylim(ymin=0)
plt.show()


Hc, bc = np.histogram(sym['rh'][cmask], bins=70, range=(0,0.03), normed=1)
Hs, bs = np.histogram(sym['rh'][np.invert(cmask)], bins=70, range=(0,0.2), normed=1)
H0, b0 = np.histogram(sym['rh'], bins=70, range=(0,0.03), normed=1)

xc = (bc[:-1]+bc[1:])/2
xs = (bs[:-1]+bs[1:])/2
x0 = (b0[:-1]+b0[1:])/2

plt.fill_between(xc, Hc, alpha=0.2, color='pink')
plt.fill_between(xs, Hs, alpha=0.2, color='royalblue')
plt.plot(x0, H0, lw=2, color='purple')
plt.xlabel('Galaxy Offset $r_\mathrm{g}$ / $h^{-1}$ Mpc', fontsize=18)
plt.xlim(0,0.03)
plt.show()


print 'Min central offset : %3.3f h^-1 kpc'%(sym['rh'][cmask].min()*1000)
print 'Max central offset : %3.3f h^-1 kpc'%(sym['rh'][cmask].max()*1000)
print 'Mean central offset : %3.3f h^-1 kpc'%(sym['rh'][cmask].mean()*1000)
print 'Median central offset : %3.3f h^-1 kpc'%(np.median(sym['rh'][cmask])*1000)

select_extreme = (sym['rh'][cmask]>0.045)
print 'Number of centrals with offset R > 45 h^-1 kpc : %d/%d (%3.3f percent)'%(fid['rh'][cmask][select_extreme].size, fid['rh'][cmask].size, fid['rh'][cmask][select_extreme].size*100./fid['rh'][cmask].size)
# Out:
# 0.015215679590689228 3.700841675197355 0.2682544616923164
# Min central offset : 0.171 h^-1 kpc
# Max central offset : 199996.425 h^-1 kpc
# Mean central offset : 77.617 h^-1 kpc
# Median central offset : 7.973 h^-1 kpc
# Number of centrals with offset R > 45 h^-1 kpc : 2949/30517 (9.663 percent)

# %%
cmask2=(fid['most_massive']==1)

Hc, bc = np.histogram(sym['rh'][cmask2], bins=90, range=(0,0.2), normed=1)
Hs, bs = np.histogram(sym['rh'][np.invert(cmask2)], bins=90, range=(0,0.2), normed=1)
H0, b0 = np.histogram(sym['rh'], bins=90, range=(0,0.2), normed=1)

xc = (bc[:-1]+bc[1:])/2
xs = (bs[:-1]+bs[1:])/2
x0 = (b0[:-1]+b0[1:])/2

print fid['rh'][np.invert(cmask2)].min(), fid['rh'][np.invert(cmask2)].max(), np.median(fid['rh'][np.invert(cmask2)])

plt.fill_between(xc, Hc, alpha=0.2, color='pink')
plt.plot(xc, Hc, color='hotpink', label='Centrals')
plt.fill_between(xs, Hs, alpha=0.2, color='royalblue')
plt.plot(xs, Hs, color='royalblue', label='Satellites')
plt.plot(x0, H0, lw=2, color='purple', label='All Galaxies')
plt.xlabel('Galaxy Offset $r_\mathrm{g}$ / $h^{-1}$ Mpc', fontsize=18)
plt.legend()
plt.ylim(ymin=0)
plt.show()


Hc, bc = np.histogram(sym['rh'][cmask2], bins=70, range=(0,0.03), normed=1)
Hs, bs = np.histogram(sym['rh'][np.invert(cmask2)], bins=70, range=(0,0.2), normed=1)
H0, b0 = np.histogram(sym['rh'], bins=70, range=(0,0.03), normed=1)

xc = (bc[:-1]+bc[1:])/2
xs = (bs[:-1]+bs[1:])/2
x0 = (b0[:-1]+b0[1:])/2

plt.fill_between(xc, Hc, alpha=0.2, color='pink')
plt.plot(xc, Hc, color='hotpink')
plt.fill_between(xs, Hs, alpha=0.2, color='royalblue')
plt.plot(x0, H0, lw=2, color='purple')
plt.xlabel('Galaxy Offset $r_\mathrm{g}$ / $h^{-1}$ Mpc', fontsize=18)
plt.xlim(0,0.03)
plt.show()


print 'Min central offset : %3.3f h^-1 kpc'%(fid['rh'][cmask2].min()*1000)
print 'Max central offset : %3.3f h^-1 kpc'%(fid['rh'][cmask2].max()*1000)
print 'Mean central offset : %3.3f h^-1 kpc'%(fid['rh'][cmask2].mean()*1000)
print 'Median central offset : %3.3f h^-1 kpc'%(np.median(fid['rh'][cmask2])*1000)

select_extreme = (sym['rh'][cmask2]>0.045)
print 'Number of centrals with offset R > 45 h^-1 kpc : %d/%d (%3.3f percent)'%(fid['rh'][cmask2][select_extreme].size, fid['rh'][cmask2].size, fid['rh'][cmask2][select_extreme].size*100./fid['rh'][cmask2].size)
# Out:
# 0.015215679590689228 0.5893180035464006 0.14261447688099826
# Min central offset : 0.171 h^-1 kpc
# Max central offset : 659.586 h^-1 kpc
# Mean central offset : 18.253 h^-1 kpc
# Median central offset : 7.975 h^-1 kpc
# Number of centrals with offset R > 45 h^-1 kpc : 2949/30517 (9.663 percent)

# %%
print fid['rh'][cmask2 & (fid['halo_id']==0)]
print fid['rh'][(fid['halo_id']==0)]
# Out:
# [0.13948623]
# [0.13948623 0.33071076 0.43249169 0.24920761 0.46836439 0.39704747
#  0.38926738 0.2628591  0.20753186 0.54090092 0.16461974 0.14420882
#  0.13253552 0.2249094 ]

# %%
select=(fid['rh']>0.05)
ids=np.unique(fid['halo_id'][select])

mask=(fid['halo_id']==0) & (fid[central_name]==1) 
xc=fid['x'][mask][0]
yc=fid['y'][mask][0]
zc=fid['z'][mask][0]

mask=(fid['halo_id']==0)
mask2 = (fid['npart_dm'][mask]==fid['npart_dm'][mask].max())
xm=fid['x'][mask][mask2][0]
ym=fid['y'][mask][mask2][0]
zm=fid['z'][mask][mask2][0]

x0 = 37384.9/1000
y0 = 40500.9/1000
z0 = 60814.7/1000

R = np.sqrt((xc-x0)**2 + (yc-y0)**2 + (zc-z0)**2)
print R
# Out:
# 0.1394862310277697

# %%
gal=fi.FITS('/Users/hattifattener/Documents/ias/mbii/subhalo_cat-nthreshold5-proj+3d.fits')['baryons'].read()
dm=fi.FITS('/Users/hattifattener/Documents/ias/mbii/subhalo_cat-nthreshold5-proj+3d.fits')['dm'].read()

hid = fi.FITS('/Users/hattifattener/Documents/ias/mbii/cats/mbii-subhalos-haloids.fits')[-1].read()

# %%
mask=np.isfinite(gal['x']) & np.isfinite(gal['y']) & np.isfinite(gal['z'])
mask2 = (hid==0)
x = gal['x'][mask & mask2]/1000
y = gal['y'][mask & mask2]/1000
z = gal['z'][mask & mask2]/1000


print x.size
plt.title('$xy$', fontsize=21)
plt.hist2d(x,y,bins=100,range=((35,45), (35,45)), cmap='Paired')
plt.plot(x0,y0,'x',color='k', ms=10, mew=2)
plt.plot(xc,yc,'+',color='white', ms=10, mew=2)
plt.plot(xm,ym,'^',color='pink', mec='pink',ms=5, mew=2)
plt.show()

plt.title('$yz$', fontsize=21)
plt.hist2d(y,z,bins=100, range=((35,45),(55,65)), cmap='Paired')
plt.plot(y0,z0,'x',color='k', ms=10, mew=2)
plt.plot(yc,zc,'+',color='white', ms=10, mew=2)
plt.plot(ym,zm,'^',color='pink', mec='pink',ms=5, mew=2)
plt.show()


plt.title('$xz$', fontsize=21)
plt.hist2d(x,z,bins=100, range=((34,44), (55,65)),cmap='Paired')
plt.plot(x0,z0,'x',color='k', ms=10, mew=2)
plt.plot(xc,zc,'+',color='white', ms=10, mew=2)
plt.plot(xm,zm,'^',color='pink', mec='pink',ms=5, mew=2)
plt.show()



plt.title('$xy$', fontsize=21)
plt.xlim(x0-0.1,x0+0.1)
plt.ylim(y0-0.1,y0+0.1)
plt.plot(x,y,'.',color='pink')
plt.plot(x0,y0,'x',color='k', ms=10, mew=2)
plt.plot(xc,yc,'+',color='blue', ms=10, mew=2)
plt.plot(xm,ym,'^',color='hotpink', mec='hotpink',ms=5, mew=2)
plt.show()

plt.title('$xy$', fontsize=21)
plt.xlim(x0-0.1,x0+0.1)
plt.ylim(y0-0.1,y0+0.1)
plt.plot(fid['x'][(fid['halo_id']==0)], fid['y'][(fid['halo_id']==0)], '.', color='pink')
plt.plot(x0,y0,'x',color='k', ms=10, mew=2)
plt.plot(xc,yc,'+',color='blue', ms=10, mew=2)
plt.show()
# Out:
# 17449

# %%
ids=np.unique(fid['halo_id'])
Mm = np.array([fid['matter_mass'][(fid['halo_id']==i)].sum() for i in ids])
Ms = np.array([fid['stellar_mass'][(fid['halo_id']==i)].sum() for i in ids])
Mg = np.array([fid['gas_mass'][(fid['halo_id']==i)].sum() for i in ids])
Ng = np.array([len(fid['gas_mass'][(fid['halo_id']==i)] ) for i in ids])
Ng=Ng.astype(float)

Mmtot = np.sum(Mm)
Mstot = np.sum(Ms)
Mgtot = np.sum(Mg)
Ngtot = np.sum(Ng)
              
print Ng
# Out:
# [14. 16.  8. ...  1.  1.  1.]

# %%
plt.plot(Mg/Mgtot, color='plum', lw=2, ls=':', label='Gas Mass')
plt.plot(Ms/Mstot, color='pink', lw=2, ls='--', label='Stellar Mass')
plt.plot(Mm/Mmtot, color='purple', lw=2, label='Matter Mass', alpha=0.7)
#plt.plot(Ng/Ngtot, color='hotpink', lw=2, ls='-.', label='No. of Galaxies')
plt.xscale('log')
plt.yscale('log')

plt.ylabel('Fraction of total', fontsize=18)
plt.xlabel('Halo Number', fontsize=18)
plt.legend()

# %%
cumMm = np.array([Mm[:i+1].sum() for i in xrange(len(ids)) ])
cumMg = np.array([Mg[:i+1].sum() for i in xrange(len(ids)) ])
cumMs = np.array([Ms[:i+1].sum() for i in xrange(len(ids)) ])
cumNg = np.array([Ng[:i+1].sum() for i in xrange(len(ids)) ])

# %%
plt.plot(cumMg/Mgtot, color='plum', lw=2, ls=':', label='Gas Mass')
plt.plot(cumMs/Mstot, color='pink', lw=2, ls='--', label='Stellar Mass')
plt.plot(cumMm/Mmtot, color='purple', lw=2, label='Matter Mass')
plt.plot(cumNg/Ngtot, color='hotpink', lw=2, ls='-.', label='No. of Subhalos')
plt.xscale('log')
#plt.yscale('log')

plt.ylabel('Fraction of total', fontsize=18)
plt.xlabel('Halo Number $< i$', fontsize=18)
plt.legend(loc='upper left')
