# %% [markdown]
# ## More Correlation Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

central_name='most_massive'

# %% [markdown]
# ### ED

# %%
ed = {}
ed_sym = {}
ed_sym0 = {}

base = '/Users/hattifattener/Documents/ias/mbii/2pt/ns300_nd1000/v9/'
for i in xrange(2):
    for j in xrange(2):
        ed[(i+1,j+1)] = np.loadtxt(base+'ED_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        ed_sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/galaxy/ED_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        ed_sym0[(i+1,j+1)] = np.loadtxt(base+'symmetrised/ED_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        
ed[(0,0)] = np.loadtxt(base+'ED_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
ed_sym[(0,0)] = np.loadtxt(base+'symmetrised/galaxy/ED_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
ed_sym0[(0,0)] = np.loadtxt(base+'symmetrised/ED_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T

print ed[0,0][2].sum()
print ed_sym[0,0][2].sum()

fig = plt.figure()
ax = fig.add_subplot(2, 2, 1)
plt.plot(ed[1,2][0], abs(ed[1,2][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(ed_sym[1,2][0], abs(ed_sym[1,2][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(ed_sym0[1,2][0], abs(ed_sym0[1,2][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(ed[1,2][0], ed[1,2][1], yerr=ed[1,2][-1], linestyle='none', color='purple')
plt.errorbar(ed_sym[1,2][0], abs(ed_sym[1,2][1]), yerr=ed_sym[1,2][-1], linestyle='none', color='plum')
plt.errorbar(ed_sym0[1,2][0], abs(ed_sym0[1,2][1]), yerr=ed_sym0[1,2][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-5,0.9)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('ED Correlation', fontsize=18)
ax.annotate('$cs$',xy=(1e1,1e-1), fontsize=20)

ax = fig.add_subplot(2, 2, 2)
plt.plot(ed[2,1][0], abs(ed[2,1][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(ed_sym[2,1][0], abs(ed_sym[2,1][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(ed_sym0[2,1][0], abs(ed_sym0[2,1][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(ed[2,1][0], ed[2,1][1], yerr=ed[2,1][-1], linestyle='none', color='purple')
plt.errorbar(ed_sym[2,1][0], abs(ed_sym[2,1][1]), yerr=ed_sym[2,1][-1], linestyle='none', color='plum')
plt.errorbar(ed_sym0[2,1][0], abs(ed_sym0[2,1][1]), yerr=ed_sym0[2,1][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-5,0.9)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
#plt.ylabel('ED Correlation', fontsize=18)
plt.yticks(visible=False)
ax.annotate('$sc$',xy=(1e1,1e-1), fontsize=20)


ax = fig.add_subplot(2, 2, 3)
plt.plot(ed[2,2][0], abs(ed[2,2][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(ed_sym[2,2][0], abs(ed_sym[2,2][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(ed_sym0[2,2][0], abs(ed_sym0[2,2][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(ed[2,2][0], ed[2,1][1], yerr=ed[2,2][-1], linestyle='none', color='purple')
plt.errorbar(ed_sym[2,2][0], abs(ed_sym[2,2][1]), yerr=ed_sym[2,2][-1], linestyle='none', color='plum')
plt.errorbar(ed_sym0[2,2][0], abs(ed_sym0[2,2][1]), yerr=ed_sym0[2,2][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-5,0.9)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
ax.annotate('$ss$',xy=(1e1,1e-1), fontsize=20)

ax = fig.add_subplot(2, 2, 4)
plt.plot(ed[0,0][0], abs(ed[0,0][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(ed_sym[0,0][0], abs(ed_sym[0,0][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(ed_sym0[0,0][0], abs(ed_sym0[0,0][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(ed[0,0][0], ed[2,1][1], yerr=ed[0,0][-1], linestyle='none', color='purple')
plt.errorbar(ed_sym[0,0][0], abs(ed_sym[0,0][1]), yerr=ed_sym[0,0][-1], linestyle='none', color='plum')
plt.errorbar(ed_sym0[0,0][0], abs(ed_sym0[0,0][1]), yerr=ed_sym0[0,0][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-5,0.9)
plt.yticks(visible=False)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
ax.annotate('all',xy=(1e1,1e-1), fontsize=20)
plt.legend(loc='lower right', fontsize=9)



plt.subplots_adjust(hspace=0,wspace=0)
plt.show()
print ed[2,1][1]
print ed_sym[2,1][1]
# Out:
# 0.013559571641905835
# 0.012973687010549769
# [0.31449577 0.12215267 0.0432589  0.01543292 0.00463024]
# [-0.00165353  0.01174953  0.03887617  0.01518093  0.00462374]

# %% [markdown]
# ### EE

# %%
ee = {}
ee_sym = {}
ee_sym0 = {}

base = '/Users/hattifattener/Documents/ias/mbii/2pt/ns300_nd1000/v9/'
for i in xrange(2):
    for j in xrange(2):
        ee[(i+1,j+1)] = np.loadtxt(base+'EE_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        ee_sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/galaxy/EE_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        ee_sym0[(i+1,j+1)] = np.loadtxt(base+'symmetrised/EE_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        
ee[(0,0)] = np.loadtxt(base+'EE_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
ee_sym[(0,0)] = np.loadtxt(base+'symmetrised/galaxy/EE_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
ee_sym0[(0,0)] = np.loadtxt(base+'symmetrised/EE_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T



fig = plt.figure()
ax = fig.add_subplot(2, 2, 1)
plt.plot(ee[1,2][0], abs(ee[1,2][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(ee_sym[1,2][0], abs(ee_sym[1,2][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(ee_sym0[1,2][0], abs(ee_sym0[1,2][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(ee[1,2][0], ee[1,2][1], yerr=ee[1,2][-1], linestyle='none', color='purple')
plt.errorbar(ee_sym[1,2][0], abs(ee_sym[1,2][1]), yerr=ee_sym[1,2][-1], linestyle='none', color='plum')
plt.errorbar(ee_sym0[1,2][0], abs(ee_sym0[1,2][1]), yerr=ee_sym0[1,2][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-6,0.9)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('EE Correlation', fontsize=18)
ax.annotate('$cs$',xy=(1e1,1e-1), fontsize=20)

ax = fig.add_subplot(2, 2, 2)
plt.plot(ee[2,1][0], abs(ee[2,1][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(ee_sym[2,1][0], abs(ee_sym[2,1][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(ee_sym0[2,1][0], abs(ee_sym0[2,1][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(ee[2,1][0], ee[2,1][1], yerr=ee[2,1][-1], linestyle='none', color='purple')
plt.errorbar(ee_sym[2,1][0], abs(ee_sym[2,1][1]), yerr=ee_sym[2,1][-1], linestyle='none', color='plum')
plt.errorbar(ee_sym0[2,1][0], abs(ee_sym0[2,1][1]), yerr=ee_sym0[2,1][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-6,0.9)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
#plt.ylabel('ED Correlation', fontsize=18)
plt.yticks(visible=False)
ax.annotate('$sc$',xy=(1e1,1e-1), fontsize=20)


ax = fig.add_subplot(2, 2, 3)
plt.plot(ee[2,2][0], abs(ee[2,2][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(ee_sym[2,2][0], abs(ee_sym[2,2][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(ee_sym0[2,2][0], abs(ee_sym0[2,2][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(ee[2,2][0], ee[2,1][1], yerr=ee[2,2][-1], linestyle='none', color='purple')
plt.errorbar(ee_sym[2,2][0], abs(ee_sym[2,2][1]), yerr=ee_sym[2,2][-1], linestyle='none', color='plum')
plt.errorbar(ee_sym0[2,2][0], abs(ee_sym0[2,2][1]), yerr=ee_sym0[2,2][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-6,0.9)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
ax.annotate('$ss$',xy=(1e1,1e-1), fontsize=20)

ax = fig.add_subplot(2, 2, 4)
plt.plot(ee[0,0][0], abs(ee[0,0][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(ee_sym[0,0][0], abs(ee_sym[0,0][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(ee_sym0[0,0][0], abs(ee_sym0[0,0][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(ee[0,0][0], ee[2,1][1], yerr=ee[0,0][-1], linestyle='none', color='purple')
plt.errorbar(ee_sym[0,0][0], abs(ee_sym[0,0][1]), yerr=ee_sym[0,0][-1], linestyle='none', color='plum')
plt.errorbar(ee_sym0[0,0][0], abs(ee_sym0[0,0][1]), yerr=ee_sym0[0,0][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-6,0.9)
plt.yticks(visible=False)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
ax.annotate('all',xy=(1e1,1e-1), fontsize=20)
plt.legend(loc='lower right', fontsize=9)



plt.subplots_adjust(hspace=0,wspace=0)
plt.show()
print ee[2,1][1]
print ee_sym[2,1][1]
# Out:
# [0.08628839 0.0320108  0.00418563 0.00057696 0.0001655 ]
# [ 8.47760922e-03  6.95572764e-03  1.08874339e-03 -2.34406993e-04
#  -3.78197388e-05]

# %% [markdown]
# ### $w_{g +}$

# %%
gi = {}
gi_sym = {}
gi_sym0 = {}

base = '/Users/hattifattener/Documents/ias/mbii/2pt/ns300_nd1000/v9/'
for i in xrange(2):
    for j in xrange(2):
        gi[(i+1,j+1)] = np.loadtxt(base+'GIplus_proj_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        gi_sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/galaxy/GIplus_proj_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        gi_sym0[(i+1,j+1)] = np.loadtxt(base+'symmetrised/GIplus_proj_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        
gi[(0,0)] = np.loadtxt(base+'GIplus_proj_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
gi_sym[(0,0)] = np.loadtxt(base+'symmetrised/galaxy/GIplus_proj_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
gi_sym0[(0,0)] = np.loadtxt(base+'symmetrised/GIplus_proj_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T



fig = plt.figure()
ax = fig.add_subplot(2, 2, 1)
plt.plot(gi[1,2][0], abs(gi[1,2][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(gi_sym[1,2][0], abs(gi_sym[1,2][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(gi_sym0[1,2][0], abs(gi_sym0[1,2][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(gi[1,2][0], gi[1,2][1], yerr=gi[1,2][-1], linestyle='none', color='purple')
plt.errorbar(gi_sym[1,2][0], abs(gi_sym[1,2][1]), yerr=gi_sym[1,2][-1], linestyle='none', color='plum')
plt.errorbar(gi_sym0[1,2][0], abs(gi_sym0[1,2][1]), yerr=gi_sym0[1,2][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-2,8.1)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('$w_{g+}(r_\mathrm{p})$', fontsize=18)
ax.annotate('$cs$',xy=(1e1,1.7), fontsize=20)

ax = fig.add_subplot(2, 2, 2)
plt.plot(gi[2,1][0], abs(gi[2,1][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(gi_sym[2,1][0], abs(gi_sym[2,1][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(gi_sym0[2,1][0], abs(gi_sym0[2,1][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(gi[2,1][0], gi[2,1][1], yerr=gi[2,1][-1], linestyle='none', color='purple')
plt.errorbar(gi_sym[2,1][0], abs(gi_sym[2,1][1]), yerr=gi_sym[2,1][-1], linestyle='none', color='plum')
plt.errorbar(gi_sym0[2,1][0], abs(gi_sym0[2,1][1]), yerr=gi_sym0[2,1][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-2,8.1)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
#plt.ylabel('ED Correlation', fontsize=18)
plt.yticks(visible=False)
ax.annotate('$sc$',xy=(1e1,1.7), fontsize=20)


ax = fig.add_subplot(2, 2, 3)
plt.plot(gi[2,2][0], abs(ee[2,2][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(gi_sym[2,2][0], abs(gi_sym[2,2][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(gi_sym0[2,2][0], abs(gi_sym0[2,2][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(gi[2,2][0], gi[2,1][1], yerr=gi[2,2][-1], linestyle='none', color='purple')
plt.errorbar(gi_sym[2,2][0], abs(gi_sym[2,2][1]), yerr=gi_sym[2,2][-1], linestyle='none', color='plum')
plt.errorbar(gi_sym0[2,2][0], abs(gi_sym0[2,2][1]), yerr=gi_sym0[2,2][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-2,8.1)
plt.xlabel('$r_\mathrm{p}$ / $h^{-1}$ Mpc', fontsize=18)
ax.annotate('$ss$',xy=(1e1,1.7), fontsize=20)

ax = fig.add_subplot(2, 2, 4)
plt.plot(gi[0,0][0], abs(gi[0,0][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(gi_sym[0,0][0], abs(gi_sym[0,0][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(gi_sym0[0,0][0], abs(gi_sym0[0,0][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(gi[0,0][0], gi[2,1][1], yerr=gi[0,0][-1], linestyle='none', color='purple')
plt.errorbar(gi_sym[0,0][0], abs(gi_sym[0,0][1]), yerr=gi_sym[0,0][-1], linestyle='none', color='plum')
plt.errorbar(gi_sym0[0,0][0], abs(gi_sym0[0,0][1]), yerr=gi_sym0[0,0][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-2,8.1)
plt.yticks(visible=False)
plt.xlabel('$r_\mathrm{p}$ / $h^{-1}$ Mpc', fontsize=18)
ax.annotate('all',xy=(1e1,1.7), fontsize=20)
plt.legend(loc='upper left', fontsize=8)



plt.subplots_adjust(hspace=0,wspace=0)
plt.show()

# %% [markdown]
# ### $w_{\delta +}$

# %%
gi = {}
gi_sym = {}
gi_sym0 = {}

base = '/Users/hattifattener/Documents/ias/mbii/2pt/ns300_nd1000/v9/'
for i in xrange(2):
    for j in xrange(2):
        gi[(i+1,j+1)] = np.loadtxt(base+'GIplus_proj_m_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        gi_sym[(i+1,j+1)] = np.loadtxt(base+'symmetrised/galaxy/GIplus_proj_m_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        gi_sym0[(i+1,j+1)] = np.loadtxt(base+'symmetrised/GIplus_proj_m_corr_%d%d_splitby%s.txt'%(i+1,j+1,central_name)).T
        
gi[(0,0)] = np.loadtxt(base+'GIplus_proj_m_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
gi_sym[(0,0)] = np.loadtxt(base+'symmetrised/galaxy/GIplus_proj_m_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T
gi_sym0[(0,0)] = np.loadtxt(base+'symmetrised/GIplus_proj_m_corr_%d%d_splitby%s.txt'%(0,0,central_name)).T



fig = plt.figure()
ax = fig.add_subplot(2, 2, 1)
plt.plot(gi[1,2][0], abs(gi[1,2][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(gi_sym[1,2][0], abs(gi_sym[1,2][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(gi_sym0[1,2][0], abs(gi_sym0[1,2][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(gi[1,2][0], gi[1,2][1], yerr=gi[1,2][-1], linestyle='none', color='purple')
plt.errorbar(gi_sym[1,2][0], abs(gi_sym[1,2][1]), yerr=gi_sym[1,2][-1], linestyle='none', color='plum')
plt.errorbar(gi_sym0[1,2][0], abs(gi_sym0[1,2][1]), yerr=gi_sym0[1,2][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-2,8.1)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
plt.ylabel('$w_{\delta+}(r_\mathrm{p})$', fontsize=18)
ax.annotate('$cs$',xy=(1e1,1.7), fontsize=20)

ax = fig.add_subplot(2, 2, 2)
plt.plot(gi[2,1][0], abs(gi[2,1][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(gi_sym[2,1][0], abs(gi_sym[2,1][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(gi_sym0[2,1][0], abs(gi_sym0[2,1][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(gi[2,1][0], gi[2,1][1], yerr=gi[2,1][-1], linestyle='none', color='purple')
plt.errorbar(gi_sym[2,1][0], abs(gi_sym[2,1][1]), yerr=gi_sym[2,1][-1], linestyle='none', color='plum')
plt.errorbar(gi_sym0[2,1][0], abs(gi_sym0[2,1][1]), yerr=gi_sym0[2,1][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-2,8.1)
plt.xlabel('$r$ / $h^{-1}$ Mpc', fontsize=18)
#plt.ylabel('ED Correlation', fontsize=18)
plt.yticks(visible=False)
ax.annotate('$sc$',xy=(1e1,1.7), fontsize=20)


ax = fig.add_subplot(2, 2, 3)
plt.plot(gi[2,2][0], abs(ee[2,2][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(gi_sym[2,2][0], abs(gi_sym[2,2][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(gi_sym0[2,2][0], abs(gi_sym0[2,2][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(gi[2,2][0], gi[2,1][1], yerr=gi[2,2][-1], linestyle='none', color='purple')
plt.errorbar(gi_sym[2,2][0], abs(gi_sym[2,2][1]), yerr=gi_sym[2,2][-1], linestyle='none', color='plum')
plt.errorbar(gi_sym0[2,2][0], abs(gi_sym0[2,2][1]), yerr=gi_sym0[2,2][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-2,8.1)
plt.xlabel('$r_\mathrm{p}$ / $h^{-1}$ Mpc', fontsize=18)
ax.annotate('$ss$',xy=(1e1,1.7), fontsize=20)

ax = fig.add_subplot(2, 2, 4)
plt.plot(gi[0,0][0], abs(gi[0,0][1]), color='purple', lw=2, label='Unsymmetrised')
plt.plot(gi_sym[0,0][0], abs(gi_sym[0,0][1]), color='plum', lw=2, ls='--', label='Symmetrised (galaxy-galaxy)')
plt.plot(gi_sym0[0,0][0], abs(gi_sym0[0,0][1]), color='k', lw=2, ls=':', label='Symmetrised (galaxy-mass)')
plt.errorbar(gi[0,0][0], gi[2,1][1], yerr=gi[0,0][-1], linestyle='none', color='purple')
plt.errorbar(gi_sym[0,0][0], abs(gi_sym[0,0][1]), yerr=gi_sym[0,0][-1], linestyle='none', color='plum')
plt.errorbar(gi_sym0[0,0][0], abs(gi_sym0[0,0][1]), yerr=gi_sym0[0,0][-1], linestyle='none', color='k')
plt.xscale('log')
ax.set_yscale('log', nonposy="clip")
plt.ylim(1e-2,8.1)
plt.yticks(visible=False)
plt.xlabel('$r_\mathrm{p}$ / $h^{-1}$ Mpc', fontsize=18)
ax.annotate('all',xy=(1e1,1.7), fontsize=20)
plt.legend(loc='upper left', fontsize=8)



plt.subplots_adjust(hspace=0,wspace=0)
plt.show()
